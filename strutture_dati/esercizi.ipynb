# %% [markdown]
# Esercizio 1.1: Manipolazione Base
# File: liste_base.py
# Obiettivo: Familiarizzare con i metodi base delle liste.
#
# Consegna:
# Creare una lista server contenente: ["web01", "db01", "cache01"]
# Aggiungere "backup01" alla fine
# Inserire "proxy01" all'inizio (indice 0)
# Rimuovere "cache01"
# Stampare la lista finale e la sua lunghezza
#
# Output Atteso:
# ['proxy01', 'web01', 'db01', 'backup01']
# Numero server: 4

# %%
lista_server:list[str]=["web01", "db01", "cache01"]
print(f"Lista iniziale:\n{lista_server}\n")
lista_server.append("backup01")
print(f"Lista con 'backup01' alla fine:\n{lista_server}\n")
lista_server.insert(0,"proxy01")
print(f"Lista con 'proxy01' all'inizio:\n{lista_server}\n")
#da_rimuovere:str = lista_server.index("cache01")
#lista_server.pop(da_rimuovere)
lista_server.pop(lista_server.index("cache01"))    
print(f"Lista senza 'cache01':\n{lista_server}\n")
print(f"Lista finale:\n {lista_server}\n")
print(f"Numero server: {len(lista_server)}")
# Out:
# Lista iniziale:
# ['web01', 'db01', 'cache01']
#
# Lista con 'backup01' alla fine:
# ['web01', 'db01', 'cache01', 'backup01']
#
# Lista con 'proxy01' all'inizio:
# ['proxy01', 'web01', 'db01', 'cache01', 'backup01']
#
# Lista senza 'cache01':
# ['proxy01', 'web01', 'db01', 'backup01']
#
# Lista finale:
#  ['proxy01', 'web01', 'db01', 'backup01']
#
# Numero server: 4

# %% [markdown]
# Esercizio 1.2: Slicing e Accesso
# File: slicing.py
# Obiettivo: Praticare l'accesso agli elementi e lo slicing.
# Consegna:
# Creare una lista temperature contenente: [15, 18, 22, 25, 28, 30, 27, 24, 20]
# Stampare la prima temperatura
# Stampare l'ultima temperatura
# Stampare le temperature dalla posizione 2 alla 5 (esclusa)
# Stampare tutte le temperature con step 2 (saltando una ogni due)
#
# Output Atteso:
# Prima temperatura: 15
# Ultima temperatura: 20
# Temperature [2:5]: [22, 25, 28]
# Ogni due: [15, 22, 28, 27, 20]

# %%
temperature_list:list[int]=[15, 18, 22, 25, 28, 30, 27, 24, 20]
print(f"Lista iniziale:\n{temperature_list}\n")
print(f"Prima temperatura:\n{temperature_list[0]}\n")
print(f"Ultima temperatura:\n{temperature_list[-1]}\n") #oppure print(temperature_list[len(temperature_list)-1])
print(f"Temperature dalla posizione 2 alla 5 (esclusa):\n{temperature_list[2:5]}\n") #consideriamo che partiamo dallo 0 per le posizioni: 15 posizione 0, 18 posizione 1, 22 **posizione 2**, 25 .., 28.., 30 **posizione 5 da escludere**, 27, 24, 20
print(f"Temperature con step 2 (saltando una ogni due):\n{temperature_list[0::2]}\n")
# Out:
# Lista iniziale:
# [15, 18, 22, 25, 28, 30, 27, 24, 20]
#
# Prima temperatura:
# 15
#
# Ultima temperatura:
# 20
#
# Temperature dalla posizione 2 alla 5 (esclusa):
# [22, 25, 28]
#
# Temperature con step 2 (saltando una ogni due):
# [15, 22, 28, 27, 20]

# %% [markdown]
# Esercizio 1.3: Ordinamento e Ricerca
# File: ordinamento.py
# Obiettivo: Ordinare liste e verificare esistenza elementi.
# Consegna:
# Creare una lista prezzi contenente: [45.5, 12.0, 78.3, 23.1, 56.7]
# Creare una copia ordinata della lista (usando sorted())
# Trovare il prezzo minimo e massimo
# Verificare se 23.1 è nella lista
# Contare quanti prezzi sono maggiori di 50
#
# Output Atteso:
# Prezzi originali: [45.5, 12.0, 78.3, 23.1, 56.7]
# Prezzi ordinati: [12.0, 23.1, 45.5, 56.7, 78.3]
# Minimo: 12.0
# Massimo: 78.3
# 23.1 presente: True
# Prezzi > 50: 2

# %%
lista_prezzi:list[float]=[45.5, 12.0, 78.3, 23.1, 56.7]
lista_prezzi_ordinata =sorted(lista_prezzi)
controllo_prezzo_presente: bool = 23.1 in lista_prezzi_ordinata

print(f"Lista iniziale:\n{lista_prezzi}\n")
print(f"Copia ordinata della lista:\n{lista_prezzi_ordinata}")
print(f"Prezzo minimo:\n{lista_prezzi_ordinata[0]}") #prendo il primo elemento della lista ordinata
print(f"Prezzo massimo:\n{lista_prezzi_ordinata[-1]}") #prendo l'ultimo elemento della lista ordinata
print(f"23.1 presente:\n{controllo_prezzo_presente}")

conto: int = 0 
for i in lista_prezzi:
    if i >50:
        conto += 1

print(f"Prezzi maggiori di 50:\n{conto}")
# Out:
# Lista iniziale:
# [45.5, 12.0, 78.3, 23.1, 56.7]
#
# Copia ordinata della lista:
# [12.0, 23.1, 45.5, 56.7, 78.3]
# Prezzo minimo:
# 12.0
# Prezzo massimo:
# 78.3
# 23.1 presente:
# True
# Prezzi maggiori di 50:
# 2

# %% [markdown]
# Esercizio 2.1: Creazione e Accesso
# File: dizionari_base.py
# Obiettivo: Creare dizionari e accedere ai valori.
# Consegna:
# Creare un dizionario config con le seguenti coppie:
# "host": "192.168.1.1"
# "port": 8080
# "ssl": True
# "timeout": 30
# Stampare il valore di "host"
# Modificare "port" in 443
# Aggiungere una nuova chiave "protocol" con valore "https"
# Stampare il dizionario completo
#
# Output Atteso:
# Host: 192.168.1.1
# {'host': '192.168.1.1', 'port': 443, 'ssl': True, 'timeout': 30, 'protocol': 'https'}

# %%
config:dict[str,str|int|bool]={
    "host": "192.168.1.1",
    "port": 8080,
    "ssl": True,
    "timeout": 30
    }
print("Stampa del valore di 'host':\n" + config["host"] + "\n") #oppure print(config.get("host"))
config['port'] = 443
print(f"Modificato 'port' in 443: \n{config}\n")
config['protocol'] = "https"
print(f"Aggiungere una nuova coppia chiave valore: \n{config}\n")
# Out:
# Stampa del valore di 'host':
# 192.168.1.1
#
# Modificato 'port' in 443:
# {'host': '192.168.1.1', 'port': 443, 'ssl': True, 'timeout': 30}
#
# Aggiungere una nuova coppia chiave valore:
# {'host': '192.168.1.1', 'port': 443, 'ssl': True, 'timeout': 30, 'protocol': 'https'}

# %% [markdown]
# Esercizio 2.2: Iterazione
# File: iterazione.py
# Obiettivo: Iterare su dizionari.
# Consegna:
# Creare un dizionario utenti con le seguenti coppie:
# "alice": "admin"
# "bob": "user"
# "charlie": "guest"
# Iterare sul dizionario e stampare ogni coppia nel formato: "Username: alice, Ruolo: admin"
# Verificare se "bob" è una chiave presente
# Stampare tutte le chiavi (usernames)
# Stampare tutti i valori (ruoli)
#
# Output Atteso:
# Username: alice, Ruolo: admin
# Username: bob, Ruolo: user
# Username: charlie, Ruolo: guest
# bob presente: True
# Usernames: dict_keys(['alice', 'bob', 'charlie'])
# Ruoli: dict_values(['admin', 'user', 'guest'])

# %%
utenti:dict[str,str]={
    "alice": "admin",
    "bob": "user",
    "charlie": "guest"
    }


for chiave, valore in utenti.items():
    print(f"Username: {chiave}, Ruolo: {valore}")
if "bob" in utenti:
    presente:bool=True
    print(f"\nbob presente: {presente}\n")

print(f"Utenti: {utenti.keys()}\n")
print(f"Ruoli: {utenti.values()}\n")
# Out:
# Username: alice, Ruolo: admin
# Username: bob, Ruolo: user
# Username: charlie, Ruolo: guest
#
# bob presente: True
#
# Utenti: dict_keys(['alice', 'bob', 'charlie'])
#
# Ruoli: dict_values(['admin', 'user', 'guest'])

# %% [markdown]
# Esercizio 2.3: Conteggio Occorrenze
# File: conteggio.py
# Obiettivo: Usare dizionari per contare occorrenze.
# Consegna:
# Creare una lista voti contenente: ["A", "B", "A", "C", "B", "A", "D", "B", "C", "A"]
# Creare un dizionario vuoto conteggio
# Iterare sulla lista voti e contare quante volte appare ogni voto nel dizionario
# Stampare il dizionario finale
# Suggerimento: Usare conteggio.get(voto, 0) per gestire chiavi mancanti.
#
# Output Atteso:
# Conteggio voti: {'A': 4, 'B': 3, 'C': 2, 'D': 1}

# %%
lista_voti:list[str]=["A", "B", "A", "C", "B", "A", "D", "B", "C", "A"]
conteggio:dict[str, int]={}

for i in lista_voti:
    conteggio[i] = conteggio.get(i,0)+1
    
print(f"Conteggio voti: {conteggio}")
# Out:
# Conteggio voti: {'A': 4, 'B': 3, 'C': 2, 'D': 1}

# %% [markdown]
# Esercizio 3.1: Lista di Dizionari
# File: lista_dizionari.py
# Obiettivo: Gestire una lista di dizionari (simile a un database).
# Consegna:
# Creare una lista prodotti contenente 4 dizionari, ognuno con chiavi "nome", "prezzo", "quantita":
# {"nome": "Laptop", "prezzo": 899.99, "quantita": 5}
# {"nome": "Mouse", "prezzo": 25.50, "quantita": 50}
# {"nome": "Tastiera", "prezzo": 75.00, "quantita": 30}
# {"nome": "Monitor", "prezzo": 299.99, "quantita": 15}
# Iterare sulla lista e stampare solo i prodotti con prezzo superiore a 100
# Calcolare il valore totale dell'inventario (prezzo × quantità per ogni prodotto)
#
# Output Atteso:
# Prodotti > 100€:
# - Laptop: €899.99
# - Monitor: €299.99
#
# Valore totale inventario: €12524.80

# %%
prodotti:list[dict]=[
    {
        "nome": "Laptop",
        "prezzo": 899.99,
        "quantita": 5
    },
    {
        "nome": "Mouse",
        "prezzo": 25.50,
        "quantita": 50
    },
    {
        "nome": "Tastiera",
        "prezzo": 75.00,
        "quantita": 30
    },
    {
        "nome": "Monitor",
        "prezzo": 299.99,
        "quantita": 15
    }
]

print("Prodotti > 100€:")
for prodotto in prodotti:
    if prodotto["prezzo"]>100:
        print(f"- {prodotto['nome']}: €{prodotto['prezzo']}")
        
valore_totale_inventario=0

for prodotto in prodotti:
    valore_totale_inventario += prodotto['prezzo'] * prodotto['quantita']
    
print(f"\nValore totale inventario: €{valore_totale_inventario:.2f}")
# Out:
# Prodotti > 100€:
# - Laptop: €899.99
# - Monitor: €299.99
#
# Valore totale inventario: €12524.80
